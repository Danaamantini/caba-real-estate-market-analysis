# %%
import pandas as pd

# %%
df = pd.read_csv("../data/raw/ar_properties.csv")

# %%
df.head()
# Out:
#                          id    ad_type  start_date    end_date  created_on  \
# 0  7LoZFkSIPOTox0r32ck42Q==  Propiedad  2019-09-15  2019-10-26  2019-09-15
# 1  QsZD4OxZInNd5po5LQDRmg==  Propiedad  2019-09-15  9999-12-31  2019-09-15
# 2  qDtysoUgbnHLp0W9We+8fg==  Propiedad  2019-09-15  2019-09-25  2019-09-15
# 3  olj51zV0HFurmaZ78U0ssg==  Propiedad  2019-09-15  2019-09-25  2019-09-15
# 4  OcS1SAA5oAzjZ3Mzg3XHyg==  Propiedad  2019-09-15  2019-09-25  2019-09-15
#
#          lat        lon         l1       l2           l3  ... bathrooms  \
# 0 -26.815439 -65.312393  Argentina  Tucumán  Yerba Buena  ...       NaN
# 1 -26.839469 -65.212790  Argentina  Tucumán          NaN  ...       1.0
# 2 -31.424820 -64.181225  Argentina  Córdoba      Córdoba  ...       1.0
# 3 -31.421242 -64.190798  Argentina  Córdoba      Córdoba  ...       1.0
# 4 -31.426064 -64.180042  Argentina  Córdoba      Córdoba  ...       1.0
#
#   surface_total  surface_covered  price  currency  price_period  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 25 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   id               1000000 non-null  str
#  1   ad_type          1000000 non-null  str
#  2   start_date       1000000 non-null  str
#  3   end_date         1000000 non-null  str
#  4   created_on       1000000 non-null  str
#  5   lat              850472 non-null   float64
#  6   lon              849456 non-null   float64
#  7   l1               1000000 non-null  str
#  8   l2               1000000 non-null  str
#  9   l3               944673 non-null   str
#  10  l4               249223 non-null   str
#  11  l5               4616 non-null     str
#  12  l6               0 non-null        float64
#  13  rooms            531101 non-null   float64
#  14  bedrooms         368640 non-null   float64
#  15  bathrooms        770378 non-null   float64
# ...

# %%
df.shape
# Out:
# (1000000, 25)

# %%
df.columns
# Out:
# Index(['id', 'ad_type', 'start_date', 'end_date', 'created_on', 'lat', 'lon',
#        'l1', 'l2', 'l3', 'l4', 'l5', 'l6', 'rooms', 'bedrooms', 'bathrooms',
#        'surface_total', 'surface_covered', 'price', 'currency', 'price_period',
#        'title', 'description', 'property_type', 'operation_type'],
#       dtype='str')

# %%
df["property_type"].unique()
# Out:
# <StringArray>
# [           'Lote',    'Departamento',              'PH',            'Casa',
#          'Oficina',            'Otro', 'Local comercial',         'Cochera',
#         'Depósito',   'Casa de campo']
# Length: 10, dtype: str

# %%
df["property_type"].value_counts()
# Out:
# property_type
# Departamento       419519
# Casa               192570
# Otro               173047
# Lote                91969
# Local comercial     38371
# PH                  36784
# Oficina             27503
# Cochera             10290
# Depósito             8143
# Casa de campo        1804
# Name: count, dtype: int64

# %%
df["operation_type"].value_counts()
# Out:
# operation_type
# Venta                745268
# Alquiler             221646
# Alquiler temporal     33086
# Name: count, dtype: int64

# %%
df["l1"].value_counts()
# Out:
# l1
# Argentina         976083
# Uruguay            23146
# Estados Unidos       727
# Brasil                44
# Name: count, dtype: int64

# %%
df["l2"].value_counts()
# Out:
# l2
# Capital Federal                 288661
# Bs.As. G.B.A. Zona Norte        150293
# Buenos Aires Costa Atlántica    143963
# Santa Fe                         92080
# Bs.As. G.B.A. Zona Sur           87485
# Bs.As. G.B.A. Zona Oeste         71373
# Córdoba                          60753
# Buenos Aires Interior            21369
# Maldonado                        12319
# Mendoza                          12032
# Neuquén                          11471
# Montevideo                        8960
# Río Negro                         6902
# Entre Ríos                        5483
# Tucumán                           5404
# Misiones                          5188
# Salta                             3571
# San Luis                          2194
# Chaco                             1280
# La Pampa                          1218
# San Juan                          1206
# Chubut                            1144
# Colonia                            989
# Corrientes                         988
# ...

# %%
df["l3"].value_counts()
# Out:
# l3
# Mar del Plata         123726
# Rosario                69899
# Tigre                  44710
# Palermo                39672
# La Plata               35483
#                        ...
# Paso de los Libres         1
# Alpasinche                 1
# Las Lomitas                1
# Mina Pan de Azúcar         1
# Colonia Carrasco           1
# Name: count, Length: 1267, dtype: int64

# %%
df["l4"].value_counts()
# Out:
# l4
# Nordelta            18873
# La Plata             9862
# Ramos Mejía          7255
# Castelar             6535
# Olivos               5457
#                     ...
# Las Beatrices           1
# Norumbega               1
# La Porteña              1
# Mayor Buratovich        1
# Pavón                   1
# Name: count, Length: 982, dtype: int64

# %%
df["l5"].value_counts()
# Out:
# l5
# BarrioPortezuelo                734
# Barrio El Golf                  721
# Barrio Los Alisos               389
# Barrio Los Lagos                368
# Barrio Los Castores             265
# Barrio Los Sauces               243
# Barrio Los Tilos                212
# Barrio El Yacht                 205
# Barrio Barrancas del Lago       204
# Islas del Canal                 192
# Barrio Lagos del Golf 2         183
# Barrio Las Glorietas            171
# Barrio La Alameda               155
# Barrio Cabos del Lago           138
# Barrio La Isla                  130
# Barrio Las Caletas               83
# Enyoi                            75
# Barrio Lagos del Golf 1          66
# QBay Yacht                       36
# Barrio Residencial Pacheco 2     35
# Barrio Residencial Pacheco 1     11
# Name: count, dtype: int64

# %%
df["l6"].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
df["currency"].value_counts()
# Out:
# currency
# USD    699509
# ARS    243595
# UYU      2329
# PEN        62
# Name: count, dtype: int64

# %%
df[["start_date", "end_date", "created_on"]].head(10)
# Out:
#    start_date    end_date  created_on
# 0  2019-09-15  2019-10-26  2019-09-15
# 1  2019-09-15  9999-12-31  2019-09-15
# 2  2019-09-15  2019-09-25  2019-09-15
# 3  2019-09-15  2019-09-25  2019-09-15
# 4  2019-09-15  2019-09-25  2019-09-15
# 5  2019-09-15  2019-09-25  2019-09-15
# 6  2019-09-15  2019-09-25  2019-09-15
# 7  2019-09-15  2019-09-25  2019-09-15
# 8  2019-09-15  2019-09-25  2019-09-15
# 9  2019-09-15  2019-09-25  2019-09-15

# %%
df["start_date"].min()
# Out:
# '2019-03-01'

# %%
df["start_date"].max()
# Out:
# '2020-03-23'

# %%
((df["operation_type"] == "Venta") &
 (df["property_type"] == "Departamento") &
 (df["l2"] == "Capital Federal") &
 (df["currency"] == "USD")).sum()
# Out:
# np.int64(121442)

# %%
caba_sales = df[
    (df["operation_type"] == "Venta") &
    (df["property_type"] == "Departamento") &
    (df["l2"] == "Capital Federal") &
    (df["currency"] == "USD")
].copy()

# %%
caba_sales.shape
# Out:
# (121442, 25)

# %%
caba_sales["id"].nunique()
# Out:
# 121442
